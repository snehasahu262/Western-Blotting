# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Found GPU at: /device:GPU:0

# %%
from google.colab import drive
drive.mount('1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at 1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/

# %%
# !git clone https://github.com/tensorflow/models.git
# !git clone https://github.com/cocodataset/cocoapi.git
# !cd cocoapi/PythonAPI; make; cp -r pycocotools /content/models/research/
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 32675, done.
# remote: Total 32675 (delta 0), reused 0 (delta 0), pack-reused 32675
# Receiving objects: 100% (32675/32675), 511.54 MiB | 33.06 MiB/s, done.
# Resolving deltas: 100% (20805/20805), done.
# Checking out files: 100% (3174/3174), done.
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 959, done.
# remote: Total 959 (delta 0), reused 0 (delta 0), pack-reused 959
# Receiving objects: 100% (959/959), 11.69 MiB | 3.91 MiB/s, done.
# Resolving deltas: 100% (570/570), done.
# python setup.py build_ext --inplace
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# ...

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-tk is already the newest version (2.7.16-2~18.04).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 29 not upgraded.
# Need to get 1,818 kB of archives.
# After this operation, 7,688 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# ...

# %%
# %cd /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research

# %%
import os
os.environ['PYTHONPATH'] += ':/content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/:/content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/slim'

# %%
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# copying object_detection/protos/square_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/calibration_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/pipeline_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/ssd_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/box_predictor_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/losses_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/input_reader_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/bipartite_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/string_int_label_map_pb2.py -> build/lib/object_detection/protos
# ...

# %%
import time, psutil
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600)
# Out:
# Time remaining for this session is:  11.597657347453966

# %%
# !python object_detection/builders/model_builder_test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 3.6.8: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# ...

# %%
# %cd /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/object_detection
# Out:
# /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/object_detection

# %%
# !python model_main.py --logtostderr --train_dir=training/ --pipeline_config_path=ssd_mobilenet_v1_pets.config
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From model_main.py:109: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
# !python export_inference_graph.py \
--input_type image_tensor \
--pipeline_config_path training/ssd_mobilenet_v1_pets.config \
--trained_checkpoint_prefix training/model.ckpt-28500 \
--output_directory My_exp_graph/
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/1I-Qjvk1VevJW83-ZP9vuy_ZCc4KPLv_x/My Drive/Tensorflow1/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From export_inference_graph.py:174: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...
